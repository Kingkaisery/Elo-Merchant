# %%
import numpy as np
import pandas as pd
import time
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss

# %%
df_train = pd.read_csv('train_feature.csv')
df_test = pd.read_csv('test_feature.csv')

# %%
train_clean = pd.read_csv('train_clean.csv')
test_clean = pd.read_csv('test_clean.csv', sep='\t')

# %%
df_train.head(3)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
#
#    elapsed_time  hist_transactions_count  hist_category_1_sum  \
# 0           245                     13.0                  0.0
# 1           396                     11.0                  2.0
# 2           549                      2.0                  0.0
#
#    hist_category_1_mean  hist_category_2_1.0_mean  \
# 0              0.000000                  1.000000
# 1              0.181818                  0.818182
# 2              0.000000                  0.000000
#
#               ...               installments_purchase_amount_max  \
# 0             ...                                      -0.575835
# 1             ...                                      -0.725956
# 2             ...                                      -0.700326
#
#    installments_purchase_amount_std  city_id_purchase_amount_mean  \
# 0                               NaN                     -0.458993
# 1                               NaN                     -0.725956
# 2                               NaN                     -0.700326
#
#    city_id_purchase_amount_min  city_id_purchase_amount_max  \
# 0                    -0.606593                    -0.296112
# 1                    -0.725956                    -0.725956
# 2                    -0.700326                    -0.700326
#
#    city_id_purchase_amount_std  category_1_installments_mean  \
# 0                     0.155803                           0.0
# 1                          NaN                           1.0
# 2                          NaN                           0.0
#
#    category_1_installments_min  category_1_installments_max  \
# 0                          0.0                          0.0
# 1                          1.0                          1.0
# 2                          0.0                          0.0
#
#    category_1_installments_std
# 0                          NaN
# 1                          NaN
# 2                          NaN
#
# [3 rows x 163 columns]

# %%
train_clean.head(3)
# Out:
#   first_active_month          card_id  feature_3    target  month  year  \
# 0         2017-06-01  C_ID_92a2005557          1 -0.820283      6  2017
# 1         2017-01-01  C_ID_3d0044924f          0  0.392913      1  2017
# 2         2016-08-01  C_ID_d639edf6cd          0  0.688056      8  2016
#
#    elapsed_time  feature_1_1  feature_1_2  feature_1_3    ...     \
# 0           245            0            0            0    ...
# 1           396            0            0            0    ...
# 2           549            0            1            0    ...
#
#    new_month_lag_min  new_month_lag_max  new_category_2_3.0_mean  \
# 0                1.0                2.0                      0.0
# 1                1.0                2.0                      0.0
# 2                2.0                2.0                      0.0
#
#    new_category_2_2.0_mean  new_purchase_date_ptp  new_purchase_date_min  \
# 0                      0.0              4742309.0           1.520259e+09
# 1                      0.0              4887632.0           1.517505e+09
# 2                      0.0                    0.0           1.524937e+09
#
#    new_purchase_date_max  new_category_3_B_mean  new_city_id_nunique  outliers
# 0           1.525001e+09                    0.0                  3.0         0
# 1           1.522393e+09                    1.0                  1.0         0
# 2           1.524937e+09                    0.0                  1.0         0
#
# [3 rows x 121 columns]

# %%
df_train['outliers'] = train_clean['outliers']
df_train['target'] = train_clean['target']

# %%
df_train = df_train[df_train['outliers'] == 0]
target = df_train['target']
del df_train['target']
features = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','outliers']]
categorical_feats = [c for c in features if 'feature_' in c]

# %%
param = {'objective':'regression',
         'num_leaves': 31,
         'min_data_in_leaf': 25,
         'max_depth': 7,
         'learning_rate': 0.01,
         'lambda_l1':0.13,
         "boosting": "gbdt",
         "feature_fraction":0.85,
         'bagging_freq':8,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "verbosity": -1,
         "random_state": 2333}

# %%
# %%time
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=2333)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval= 100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target)**0.5))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60478	valid_1's rmse: 1.61613
# [200]	training's rmse: 1.57349	valid_1's rmse: 1.58931
# [300]	training's rmse: 1.55877	valid_1's rmse: 1.57884
# [400]	training's rmse: 1.54895	valid_1's rmse: 1.57295
# [500]	training's rmse: 1.54139	valid_1's rmse: 1.56928
# [600]	training's rmse: 1.53542	valid_1's rmse: 1.56711
# [700]	training's rmse: 1.53007	valid_1's rmse: 1.56576
# [800]	training's rmse: 1.52525	valid_1's rmse: 1.56457
# [900]	training's rmse: 1.52081	valid_1's rmse: 1.56379
# [1000]	training's rmse: 1.51679	valid_1's rmse: 1.5632
# [1100]	training's rmse: 1.51274	valid_1's rmse: 1.56286
# [1200]	training's rmse: 1.50895	valid_1's rmse: 1.56262
# [1300]	training's rmse: 1.50512	valid_1's rmse: 1.5623
# [1400]	training's rmse: 1.50151	valid_1's rmse: 1.56218
# [1500]	training's rmse: 1.49785	valid_1's rmse: 1.56184
# [1600]	training's rmse: 1.4943	valid_1's rmse: 1.5617
# [1700]	training's rmse: 1.49076	valid_1's rmse: 1.56165
# [1800]	training's rmse: 1.48752	valid_1's rmse: 1.56152
# [1900]	training's rmse: 1.48438	valid_1's rmse: 1.56162
# Early stopping, best iteration is:
# [1792]	training's rmse: 1.48773	valid_1's rmse: 1.5615
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.61004	valid_1's rmse: 1.59406
# [200]	training's rmse: 1.57853	valid_1's rmse: 1.56734
# [300]	training's rmse: 1.56377	valid_1's rmse: 1.55702
# [400]	training's rmse: 1.55411	valid_1's rmse: 1.55159
# [500]	training's rmse: 1.54664	valid_1's rmse: 1.54824
# [600]	training's rmse: 1.54043	valid_1's rmse: 1.54629
# [700]	training's rmse: 1.53505	valid_1's rmse: 1.545
# [800]	training's rmse: 1.53018	valid_1's rmse: 1.54403
# [900]	training's rmse: 1.52574	valid_1's rmse: 1.54349
# [1000]	training's rmse: 1.52153	valid_1's rmse: 1.54299
# [1100]	training's rmse: 1.51739	valid_1's rmse: 1.54257
# [1200]	training's rmse: 1.5137	valid_1's rmse: 1.54248
# [1300]	training's rmse: 1.50989	valid_1's rmse: 1.5424
# [1400]	training's rmse: 1.50611	valid_1's rmse: 1.5423
# [1500]	training's rmse: 1.50272	valid_1's rmse: 1.54229
# [1600]	training's rmse: 1.49942	valid_1's rmse: 1.54212
# [1700]	training's rmse: 1.49607	valid_1's rmse: 1.5421
# [1800]	training's rmse: 1.49273	valid_1's rmse: 1.54203
# [1900]	training's rmse: 1.48932	valid_1's rmse: 1.54199
# [2000]	training's rmse: 1.48604	valid_1's rmse: 1.54202
# Early stopping, best iteration is:
# [1840]	training's rmse: 1.49149	valid_1's rmse: 1.54196
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.6029	valid_1's rmse: 1.62433
# [200]	training's rmse: 1.57176	valid_1's rmse: 1.59555
# [300]	training's rmse: 1.55708	valid_1's rmse: 1.58461
# [400]	training's rmse: 1.54753	valid_1's rmse: 1.57892
# [500]	training's rmse: 1.54022	valid_1's rmse: 1.57547
# [600]	training's rmse: 1.53415	valid_1's rmse: 1.57314
# [700]	training's rmse: 1.52875	valid_1's rmse: 1.5714
# [800]	training's rmse: 1.52387	valid_1's rmse: 1.57006
# [900]	training's rmse: 1.51951	valid_1's rmse: 1.56932
# [1000]	training's rmse: 1.51533	valid_1's rmse: 1.56884
# [1100]	training's rmse: 1.51145	valid_1's rmse: 1.56848
# [1200]	training's rmse: 1.50772	valid_1's rmse: 1.56813
# [1300]	training's rmse: 1.50408	valid_1's rmse: 1.56799
# [1400]	training's rmse: 1.50056	valid_1's rmse: 1.56793
# [1500]	training's rmse: 1.49713	valid_1's rmse: 1.56779
# [1600]	training's rmse: 1.49369	valid_1's rmse: 1.56763
# [1700]	training's rmse: 1.49032	valid_1's rmse: 1.56754
# [1800]	training's rmse: 1.48687	valid_1's rmse: 1.56749
# [1900]	training's rmse: 1.48367	valid_1's rmse: 1.56745
# [2000]	training's rmse: 1.48034	valid_1's rmse: 1.56738
# [2100]	training's rmse: 1.47733	valid_1's rmse: 1.56739
# [2200]	training's rmse: 1.47414	valid_1's rmse: 1.56735
# [2300]	training's rmse: 1.47117	valid_1's rmse: 1.5673
# [2400]	training's rmse: 1.46794	valid_1's rmse: 1.56729
# [2500]	training's rmse: 1.46485	valid_1's rmse: 1.56726
# [2600]	training's rmse: 1.46179	valid_1's rmse: 1.56724
# Early stopping, best iteration is:
# [2443]	training's rmse: 1.46672	valid_1's rmse: 1.56722
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.608	valid_1's rmse: 1.60028
# [200]	training's rmse: 1.57607	valid_1's rmse: 1.57492
# [300]	training's rmse: 1.56101	valid_1's rmse: 1.5658
# [400]	training's rmse: 1.55126	valid_1's rmse: 1.56096
# [500]	training's rmse: 1.54386	valid_1's rmse: 1.55797
# [600]	training's rmse: 1.53761	valid_1's rmse: 1.55605
# [700]	training's rmse: 1.53221	valid_1's rmse: 1.55464
# [800]	training's rmse: 1.5274	valid_1's rmse: 1.55387
# [900]	training's rmse: 1.52282	valid_1's rmse: 1.55317
# [1000]	training's rmse: 1.51866	valid_1's rmse: 1.55293
# [1100]	training's rmse: 1.51482	valid_1's rmse: 1.55261
# [1200]	training's rmse: 1.51098	valid_1's rmse: 1.55238
# [1300]	training's rmse: 1.50741	valid_1's rmse: 1.55237
# [1400]	training's rmse: 1.50381	valid_1's rmse: 1.55226
# [1500]	training's rmse: 1.5002	valid_1's rmse: 1.55214
# [1600]	training's rmse: 1.49683	valid_1's rmse: 1.55215
# [1700]	training's rmse: 1.49345	valid_1's rmse: 1.55209
# [1800]	training's rmse: 1.4903	valid_1's rmse: 1.55208
# [1900]	training's rmse: 1.48704	valid_1's rmse: 1.55194
# [2000]	training's rmse: 1.48387	valid_1's rmse: 1.55206
# Early stopping, best iteration is:
# [1878]	training's rmse: 1.48773	valid_1's rmse: 1.55193
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.60482	valid_1's rmse: 1.61734
# [200]	training's rmse: 1.57347	valid_1's rmse: 1.58982
# [300]	training's rmse: 1.5587	valid_1's rmse: 1.57878
# [400]	training's rmse: 1.54907	valid_1's rmse: 1.573
# [500]	training's rmse: 1.54159	valid_1's rmse: 1.56938
# [600]	training's rmse: 1.53553	valid_1's rmse: 1.56708
# [700]	training's rmse: 1.53026	valid_1's rmse: 1.56534
# [800]	training's rmse: 1.52552	valid_1's rmse: 1.56431
# [900]	training's rmse: 1.52116	valid_1's rmse: 1.56362
# [1000]	training's rmse: 1.51711	valid_1's rmse: 1.56312
# [1100]	training's rmse: 1.51318	valid_1's rmse: 1.56277
# [1200]	training's rmse: 1.50926	valid_1's rmse: 1.5624
# [1300]	training's rmse: 1.50574	valid_1's rmse: 1.56217
# [1400]	training's rmse: 1.50189	valid_1's rmse: 1.56203
# [1500]	training's rmse: 1.4985	valid_1's rmse: 1.56185
# [1600]	training's rmse: 1.49508	valid_1's rmse: 1.56165
# [1700]	training's rmse: 1.49191	valid_1's rmse: 1.56165
# [1800]	training's rmse: 1.48875	valid_1's rmse: 1.56167
# Early stopping, best iteration is:
# [1664]	training's rmse: 1.49306	valid_1's rmse: 1.56158
# CV score: 1.55686
# Wall time: 7min 18s

# %%
model_without_outliers = pd.DataFrame({"card_id":df_test["card_id"].values})
model_without_outliers["target"] = predictions

# %%
df_train = pd.read_csv('train_feature.csv')
df_test = pd.read_csv('test_feature.csv')

# %%
df_train['outliers'] = train_clean['outliers']

# %%
target = df_train['outliers']
del df_train['outliers']

# %%
features = [c for c in df_train.columns if c not in ['card_id', 'first_active_month']]
categorical_feats = [c for c in features if 'feature_' in c]

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'binary',
         'max_depth': 6,
         'learning_rate': 0.01,
         "boosting": "rf",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "bagging_seed": 11,
         "metric": 'binary_logloss',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "random_state": 2333}

# %%
# %%time
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

start = time.time()


for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx], categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx], categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(log_loss(target, oof)))
# Out:
# fold n°0
# D:\Users\s88323\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:1184: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\Users\s88323\AppData\Local\Continuum\anaconda3\lib\site-packages\lightgbm\basic.py:742: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0444838	valid_1's binary_logloss: 0.0470287
# [200]	training's binary_logloss: 0.0444626	valid_1's binary_logloss: 0.0470584
# Early stopping, best iteration is:
# [27]	training's binary_logloss: 0.0444635	valid_1's binary_logloss: 0.0469785
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.045163	valid_1's binary_logloss: 0.0460864
# [200]	training's binary_logloss: 0.0450993	valid_1's binary_logloss: 0.0460215
# [300]	training's binary_logloss: 0.0451133	valid_1's binary_logloss: 0.046037
# [400]	training's binary_logloss: 0.0450984	valid_1's binary_logloss: 0.0460208
# Early stopping, best iteration is:
# [203]	training's binary_logloss: 0.0450944	valid_1's binary_logloss: 0.0460152
# fold n°2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0453457	valid_1's binary_logloss: 0.0446483
# [200]	training's binary_logloss: 0.0452889	valid_1's binary_logloss: 0.0446352
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.0454117	valid_1's binary_logloss: 0.0443946
# fold n°3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0441312	valid_1's binary_logloss: 0.050127
# [200]	training's binary_logloss: 0.0440649	valid_1's binary_logloss: 0.0500714
# [300]	training's binary_logloss: 0.0440788	valid_1's binary_logloss: 0.0500925
# [400]	training's binary_logloss: 0.0440675	valid_1's binary_logloss: 0.0500831
# Early stopping, best iteration is:
# [206]	training's binary_logloss: 0.0440579	valid_1's binary_logloss: 0.0500662
# fold n°4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0448301	valid_1's binary_logloss: 0.0452093
# [200]	training's binary_logloss: 0.0448588	valid_1's binary_logloss: 0.0452657
# [300]	training's binary_logloss: 0.0448714	valid_1's binary_logloss: 0.0452724
# Early stopping, best iteration is:
# [102]	training's binary_logloss: 0.0448151	valid_1's binary_logloss: 0.0452002
# CV score: 0.04653
# Wall time: 1min 22s

# %%
df_outlier_prob = pd.DataFrame({"card_id":df_test["card_id"].values})
df_outlier_prob["target"] = predictions
df_outlier_prob.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab  0.107539
# 1  C_ID_130fd0cbdd  0.002639
# 2  C_ID_b709037bc5  0.004452
# 3  C_ID_d27d835a9f  0.002200
# 4  C_ID_2b5e3df5c2  0.002200

# %%
outlier_id = pd.DataFrame(df_outlier_prob.sort_values(by='target',ascending = False).head(25000)['card_id'])

# %%
best_submission = pd.read_csv('submit.csv')

# %%
most_likely_liers = best_submission.merge(outlier_id,how='right')
most_likely_liers.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -4.706186
# 1  C_ID_6d8dba8475 -0.495479
# 2  C_ID_7f1041e8e1 -5.099685
# 3  C_ID_22e4a47c72  0.633485
# 4  C_ID_b54cfad8b2 -0.943807

# %%
# %%time
for card_id in most_likely_liers['card_id']:
    model_without_outliers.loc[model_without_outliers['card_id']==card_id,'target']\
    = most_likely_liers.loc[most_likely_liers['card_id']==card_id,'target'].values
# Out:
# Wall time: 5min 56s

# %%
model_without_outliers.to_csv("submission.csv", index=False)
